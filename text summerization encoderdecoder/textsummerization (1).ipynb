# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

porter = PorterStemmer()

from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout, Activation

# %%
def cleanText(text):
    text = text.lower()
    text = re.sub('[^\w\s]','',text)
    
    text.strip()
    
    txt=[]
    for w in text.split():
        stemWord = porter.stem(w)
        txt.append(stemWord)
    txt = ' '.join(txt)
    return txt

# %%
train_df = pd.read_csv('/kaggle/input/textsummarization-data/train.csv')
test_df = pd.read_csv('/kaggle/input/textsummarization-data/test.csv')
val_df = pd.read_csv('/kaggle/input/textsummarization-data/val.csv')
train_df.shape
# Out:
# (20000, 2)

# %%
pre = pd.DataFrame()
pre['text'] = pd.concat([train_df['document'], val_df['document'], test_df['document']], ignore_index=True)
pre['summary'] = pd.concat([train_df['summary'], val_df['summary'], test_df['summary']], ignore_index=True)
pre.head()
# Out:
#                                                 text  \
# 0  jason blake of the islanders will miss the res...
# 1  the u.s. military on wednesday captured a wife...
# 2  craig bellamy 's future at west ham appeared i...
# 3  cambridge - when barack obama sought advice be...
# 4  wall street held on to steep gains on monday ,...
#
#                                              summary
# 0                       blake missing rest of season
# 1  u.s. arrests wife and daughter of saddam deput...
# 2       west ham drops bellamy amid transfer turmoil
# 3        in search for expertise harvard looms large
# 4         wall street ends a three-day losing streak

# %%
pre['text'] = pre['text'].apply(cleanText)
pre['summary'] = pre['summary'].apply(cleanText)

# %%
pre.shape
# Out:
# (22000, 2)

# %%
pre.isnull().sum()
# Out:
# text       0
# summary    0
# dtype: int64

# %% [markdown]
# #

# %%
cnt = 0
for i in pre['text']:
    if len(i.split()) <= 70:
        cnt = cnt + 1
print(cnt / len(pre['text']))
# Out:
# 1.0

# %%
cnt = 0
for i in pre['summary']:
    if len(i.split()) <= 20:
        cnt = cnt + 1
print(cnt / len(pre['summary']))
# Out:
# 0.9997272727272727

# %%
max_text_len = 70
max_summary_len = 20

# %%
import numpy as np

cleaned_text = np.array(pre['text'])
cleaned_summary = np.array(pre['summary'])

short_text = []
short_summary = []

for i in range(len(train_df)):
    if len(cleaned_summary[i].split()) <= max_summary_len and len(cleaned_text[i].split()) <= max_text_len:
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])
        
post_pre = pd.DataFrame({'text': short_text,'summary': short_summary})

post_pre.head(2)
# Out:
#                                                 text  \
# 0  jason blake of the island will miss the rest o...
# 1  the us militari on wednesday captur a wife and...
#
#                                              summary
# 0                          blake miss rest of season
# 1  us arrest wife and daughter of saddam deputi t...

# %%
post_pre['summary'] = post_pre['summary'].apply(lambda x: 'sostok ' + x \
        + ' eostok')

post_pre.head(2)
# Out:
#                                                 text  \
# 0  jason blake of the island will miss the rest o...
# 1  the us militari on wednesday captur a wife and...
#
#                                              summary
# 0            sostok blake miss rest of season eostok
# 1  sostok us arrest wife and daughter of saddam d...

# %%
from sklearn.model_selection import train_test_split

x_train ,x_test, y_train, y_test = train_test_split(
    np.array(post_pre["text"]),
    np.array(post_pre["summary"]),
    test_size=0.1,
    random_state=0,
    shuffle=True,
)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_train))

# %%
x_tokenizer.word_counts.items()
# Out:
# odict_items([('the', 28632), ('second', 422), ('round', 206), ('climat', 58), ('meet', 413), ('of', 14935), ('major', 379), ('economi', 275), ('will', 1655), ('be', 1395), ('conclud', 47), ('with', 3215), ('a', 15583), ('chairman', 156), ('s', 7190), ('summari', 3), ('an', 2797), ('offici', 1692), ('attend', 85), ('told', 161), ('xinhua', 81), ('on', 7875), ('thursday', 2134), ('tivo', 2), ('inc', 165), ('and', 9165), ('nero', 1), ('ag', 57), ('germani', 205), ('were', 1026), ('set', 379), ('to', 13707), ('announc', 553), ('monday', 2035), ('that', 3514), ('they', 659), ('launch', 231), ('packag', 49), ('turn', 151), ('window', 30), ('pc', 7), ('into', 786), ('tv', 68), ('record', 263), ('just', 185), ('like', 207), ('settop', 1), ('box', 33), ('three', 622), ('us', 2132), ('soldier', 239), ('injur', 240), ('tuesday', 2244), ('when', 529), ('their', 1304), ('militari', 529), ('vehicl', 83), ('roll', 45), ('over', 1203), ('while', 297), ('patrol', 38), ('in', 12800), ('southeast', 76), ('afghanistan', 192), ('said', 4821), ('south', 632), ('korea', 298), ('send', 92), ('envoy', 72), ('china', 1132), ('thi', 955), ('week', 739), ('seek', 167), ('support', 338), ('for', 5146), ('it', 3595), ('campaign', 254), ('un', 422), ('secur', 581), ('council', 200), ('censur', 3), ('north', 322), ('sink', 21), ('warship', 23), ('hong', 339), ('kong', 335), ('hang', 44), ('seng', 20), ('enterpris', 51), ('index', 205), ('rose', 210), ('point', 410), ('or', 430), ('percent', 851), ('close', 602), ('at', 2822), ('friday', 1879), ('name', 165), ('inhous', 1), ('design', 69), ('who', 1121), ('replac', 69), ('creativ', 8), ('director', 85), ('tom', 30), ('ford', 41), ('italian', 156), ('fashion', 28), ('group', 668), ('gucci', 3), ('unveil', 65), ('press', 203), ('report', 1303), ('defens', 300), ('minist', 1249), ('radek', 4), ('sikorski', 2), ('religi', 60), ('leader', 747), ('poland', 50), ('jewish', 71), ('commun', 151), ('flank', 3), ('by', 2474), ('world', 1142), ('war', 497), ('ii', 85), ('veteran', 67), ('laid', 25), ('flower', 14), ('pray', 6), ('mark', 179), ('rd', 12), ('anniversari', 84), ('doom', 7), ('warsaw', 13), ('ghetto', 2), ('upris', 13), ('summer', 78), ('unit', 930), ('state', 1354), ('wa', 1970), ('start', 297), ('come', 181), ('out', 591), ('brutal', 24), ('recess', 51), ('unemploy', 38), ('rate', 250), ('twice', 30), ('what', 225), ('is', 1922), ('now', 137), ('recoveri', 67), ('ha', 2239), ('gone', 22), ('more', 879), ('than', 667), ('four', 403), ('year', 1677), ('guinea', 19), ('largest', 252), ('mine', 64), ('firm', 114), ('compagni', 2), ('de', 99), ('unk', 1946), ('lrb', 1757), ('rrb', 1753), ('resum', 78), ('work', 314), ('town', 141), ('capit', 314), ('union', 422), ('beaver', 1), ('improb', 2), ('run', 217), ('nation', 1193), ('championship', 223), ('came', 83), ('jar', 3), ('end', 532), ('night', 286), ('verizon', 5), ('center', 223), ('neil', 4), ('jenkin', 1), ('kick', 49), ('wale', 16), ('ralli', 147), ('from', 2451), ('firsthalf', 11), ('deficit', 59), ('beat', 227), ('argentina', 64), ('saturday', 1078), ('first', 1058), ('test', 271), ('isra', 385), ('palestinian', 412), ('welcom', 83), ('presid', 1875), ('georg', 235), ('w', 185), ('bush', 336), ('propos', 165), ('region', 410), ('peac', 355), ('confer', 148), ('but', 679), ('express', 142), ('vastli', 2), ('differ', 65), ('vision', 24), ('gather', 83), ('would', 665), ('produc', 126), ('senior', 240), ('diplomat', 130), ('plan', 629), ('visit', 421), ('congo', 45), ('later', 97), ('are', 891), ('reluct', 6), ('demand', 199), ('withdraw', 67), ('strong', 157), ('peacekeep', 85), ('forc', 580), ('sweden', 43), ('fell', 177), ('one', 760), ('full', 95), ('percentag', 14), ('lower', 180), ('due', 156), ('upsw', 3), ('labor', 108), ('market', 561), ('accord', 469), ('latest', 147), ('survey', 54), ('publish', 129), ('statist', 82), ('price', 585), ('jordan', 79), ('amman', 15), ('financi', 282), ('down', 409), ('finish', 113), ('andi', 26), ('laroch', 1), ('d ...

# %%
cnt = 0
tot_cnt = 0

for key, value in x_tokenizer.word_counts.items():
    tot_cnt = tot_cnt + 1
    if value < 5:
        cnt = cnt + 1
    
print("% of rare words in vocabulary: ", (cnt / tot_cnt) * 100)
# Out:
# % of rare words in vocabulary:  70.7153189305212

# %%
x_tokenizer = Tokenizer(num_words = tot_cnt - cnt) 
x_tokenizer.fit_on_texts(list(x_train))


x_train_seq = x_tokenizer.texts_to_sequences(x_train) 
x_test_seq = x_tokenizer.texts_to_sequences(x_test)


x_train = pad_sequences(x_train_seq,  maxlen=max_text_len, padding='post')
x_test = pad_sequences(x_test_seq, maxlen=max_text_len, padding='post')


x_voc = x_tokenizer.num_words + 1

print("Size of vocabulary in X = {}".format(x_voc))
# Out:
# Size of vocabulary in X = 6277

# %%
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_train))

cnt = 0
tot_cnt = 0

for key, value in y_tokenizer.word_counts.items():
    tot_cnt = tot_cnt + 1
    if value < 5:
        cnt = cnt + 1
    
print("% of rare words in vocabulary:",(cnt / tot_cnt) * 100)


y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_train))

 
y_train_seq = y_tokenizer.texts_to_sequences(y_train) 
y_test_seq = y_tokenizer.texts_to_sequences(y_test) 


y_train = pad_sequences(y_train_seq, maxlen=max_summary_len, padding='post')
y_test = pad_sequences(y_test_seq, maxlen=max_summary_len, padding='post')


y_voc = y_tokenizer.num_words + 1

print("Size of vocabulary in Y = {}".format(y_voc))
# Out:
# % of rare words in vocabulary: 71.4763185782995
# Size of vocabulary in Y = 3500

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping

# %%
latent_dim = 300
embedding_dim = 200


encoder_inputs = Input(shape=(max_text_len, ))


enc_emb = Embedding(x_voc, embedding_dim, trainable=True)(encoder_inputs)


encoder_lstm1 = LSTM(latent_dim, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
(encoder_output1, state_h1, state_c1) = encoder_lstm1(enc_emb)


encoder_lstm2 = LSTM(latent_dim, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
(encoder_output2, state_h2, state_c2) = encoder_lstm2(encoder_output1)


encoder_lstm3 = LSTM(latent_dim, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
(encoder_outputs, state_h, state_c) = encoder_lstm3(encoder_output2)


decoder_inputs = Input(shape=(None, ))


dec_emb_layer = Embedding(y_voc, embedding_dim, trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)


decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
(decoder_outputs, decoder_fwd_state, decoder_back_state) = \
    decoder_lstm(dec_emb, initial_state=[state_h, state_c])


decoder_dense = TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_outputs)

model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 70)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 70, 200)   │  1,255,400 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm (LSTM)         │ [(None, 70, 300), │    601,200 │ embedding[0][0]   │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, None)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ [(None, 70, 300), │    721,200 │ lstm[0][0]        │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, None, 200) │    700,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ [(None, 70, 300), │    721,200 │ lstm_1[0][0]      │
# │                     │ (None, 300),      │            │                   │
# │                     │ (None, 300)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_3 (LSTM)       │ [(None, None,     │    601,200 │ embedding_1[0][0… │
# │                     │ 300), (None,      │            │ lstm_2[0][1],     │
# │                     │ 300), (None,      │            │ lstm_2[0][2]      │
# │                     │ 300)]             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed    │ (None, None,      │  1,053,500 │ lstm_3[0][0]      │
# │ (TimeDistributed)   │ 3500)             │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,653,700 (21.57 MB)
#  Trainable params: 5,653,700 (21.57 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)

# %%
history = model.fit(
    [x_train, y_train[:, :-1]],
    y_train.reshape(y_train.shape[0], y_train.shape[1], 1)[:, 1:],
    epochs=5,
    callbacks=[es],
    batch_size=128,
    validation_data=([x_test, y_test[:, :-1]],y_test.reshape(y_test.shape[0], y_test.shape[1], 1)[:, 1:]),
    )
# Out:
# Epoch 1/5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 53s 299ms/step - loss: 3.9273 - val_loss: 2.7501
# Epoch 2/5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 292ms/step - loss: 2.7791 - val_loss: 2.7298
# Epoch 3/5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 291ms/step - loss: 2.7541 - val_loss: 2.7183
# Epoch 4/5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 290ms/step - loss: 2.7337 - val_loss: 2.7021
# Epoch 5/5
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 41s 289ms/step - loss: 2.7165 - val_loss: 2.6917

# %%
reverse_target_word_index = y_tokenizer.index_word
reverse_source_word_index = x_tokenizer.index_word
target_word_index = y_tokenizer.word_index

# %%
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs,
                      state_h, state_c])


decoder_state_input_h = Input(shape=(latent_dim, ))
decoder_state_input_c = Input(shape=(latent_dim, ))
decoder_hidden_state_input = Input(shape=(max_text_len, latent_dim))


dec_emb2 = dec_emb_layer(decoder_inputs)


(decoder_outputs2, state_h2, state_c2) = decoder_lstm(dec_emb2,
        initial_state=[decoder_state_input_h, decoder_state_input_c])


decoder_outputs2 = decoder_dense(decoder_outputs2)


decoder_model = Model([decoder_inputs] + [decoder_hidden_state_input,
                      decoder_state_input_h, decoder_state_input_c],
                      [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):

    
    (e_out, e_h, e_c) = encoder_model.predict(input_seq)

    
    target_seq = np.zeros((1, 1))

    
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        (output_tokens, h, c) = decoder_model.predict([target_seq]
                + [e_out, e_h, e_c])

        
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]

        if sampled_token != 'eostok':
            decoded_sentence += ' ' + sampled_token

        
        if sampled_token == 'eostok' or len(decoded_sentence.split()) \
            >= max_summary_len - 1:
            stop_condition = True

        
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        
        (e_h, e_c) = (h, c)

    return decoded_sentence

# %%
def seq2summary(input_seq):
    newString = ''
    for i in input_seq:
        if i != 0 and i != target_word_index['sostok'] and i \
            != target_word_index['eostok']:
            newString = newString + reverse_target_word_index[i] + ' '

    return newString


def seq2text(input_seq):
    newString = ''
    for i in input_seq:
        if i != 0:
            newString = newString + reverse_source_word_index[i] + ' '

    return newString

# %%
for i in range(0, 19):
    print ('Review:', seq2text(x_train[i]))
    print ('Original summary:', seq2summary(y_train[i]))
    print ('Predicted summary:', decode_sequence(x_train[i].reshape(1,max_text_len)))
    print ('\n')
# Out:
# Review: the second round climat meet of major economi will be conclud with a chairman s an offici attend the meet told xinhua on thursday
# Original summary: climat chang meet to be conclud with chairman summari
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: inc and ag of germani were set to announc monday that they will be launch a packag that turn a window pc into a tv record just like a box
# Original summary: new softwar turn pc into tv record
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: three us soldier were injur tuesday when their militari vehicl roll over while on patrol in southeast afghanistan the us militari said
# Original summary: three us soldier injur in afghan car accid
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: south korea will send an envoy to china thi week to seek support for it campaign for the un secur council to north korea over the sink of a warship offici said monday
# Original summary: s korea to send envoy to china over warship sink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: hong kong s hang seng china enterpris index rose point or percent to close at friday
# Original summary: hang seng china enterpris index up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: the name of three design who will replac creativ director tom ford at the italian fashion group were unveil in press report thursday
# Original summary: name of tom ford s at unveil in press report
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: defens minist and religi leader of poland s jewish commun by jewish world war ii veteran laid flower and pray tuesday to mark the rd anniversari of the doom warsaw upris
# Original summary: poland mark rd anniversari of upris
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: in the summer of the unit state wa just start to come out of a brutal recess and the unemploy rate wa percent twice what it is now in a recoveri that ha gone on for more than four year
# Original summary: for more employ number look deeper
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: guinea s largest mine firm de unk de unk lrb unk rrb resum work on friday at unk a town north of the capit a union offici said
# Original summary: guinea s giant mine firm resum work
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: the unk state run at a nation championship came to a end thursday night at the verizon center
# Original summary: unk state from an unk dream
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: kick for point and wale ralli from a point firsthalf deficit to beat argentina saturday in the first test
# Original summary: wale ralli from point deficit down
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: isra and palestinian on tuesday welcom presid georg w bush s propos for a region peac confer but express differ vision for what the gather would produc
# Original summary: israel palestinian welcom bush s call for intern peac confer
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Predicted summary:  us s unk to the
#
#
# Review: senior un diplomat and offici plan to visit congo later thi week are reluct to support for congo s demand that the un withdraw it strong peacekeep forc
# Original summary: un reluct to pull out congo peacekeep
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: sweden s unemploy rate fell to percent in one full percentag point lower than in due to the in the labor market accord to the latest labor forc survey lrb unk rrb publish by statist sweden on monday
# Original summary: swedish unemploy rate down in
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: the price index of jordan s amman financi market close at point on tuesday point down from monday s finish
# Original summary: jordan s stock market index close down
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: andi drove in three run with two hit and a sacrific fli to lead the unit state over south africa and into the quarterfin of the basebal world cup on tuesday
# Original summary: us cuba move into basebal world cup quarterfin
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
#
#
# Review: asian stock market mostli retreat on tuesday as trader cash in on massiv gain in the previou session after china vow to make it yuan currenc more flexibl
# Original summary: most asian share down as trader sell off gain
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: germani s davi cup tenni team got a littl reveng saturday when the doubl pair of marc kevin and david roll over spaniard carlo costa and alex
# Original summary: german doubl team roll to victori over spain in davi cup
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Predicted summary:  us s unk to the
#
#
# Review: denni return to seattl thi week for the first time sinc the fire him as their coach after the season
# Original summary: unk coach return to seattl
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Predicted summary:  us s unk to the
